# %%
from processing import process_color_maps
# %matplotlib inline

# %%
img_link = 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/10/Candy_in_Damascus.jpg/1920px-Candy_in_Damascus.jpg'
n_colors = 5

process_color_maps(n_colors, img_link)
# Out:
# ...
# K-means cluster centers in RGB space:
# RGB values:
#             0              1              2              3              4
# 0  [68 29 26]  [184  56  48]  [239 147 103]  [213 198 234]  [126 110 121]
#
#
# HEX color values:
#          0        1        2        3        4
# 0  #441d1a  #b83830  #ef9367  #d5c6ea  #7e6e79
#
#
# ...
# Self-Organized Map of 25 randomly picked colors:
# RGB values:
#                0              1              2              3              4
# 0  [230 111  57]  [228  39  43]  [177  36  33]  [105  21  21]     [32 10  9]
# 1  [242 144  74]  [238  85 102]  [181  79  59]  [129  56  43]     [60 49 45]
# 2  [250 188  95]  [234 138 126]  [176 104  92]  [126  94  79]     [86 80 82]
# 3  [243 189 166]  [234 161 184]  [188 150 174]  [150 128 123]  [116 114 107]
# 4  [239 231 250]  [220 193 238]  [181 168 229]  [152 149 197]  [125 123 153]
#
#
# HEX color values:
#          0        1        2        3        4
# 0  #e66f39  #e4272b  #b12421  #691515  #200a09
# ...
